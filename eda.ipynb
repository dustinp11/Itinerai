# %%
import googlemaps

key = "AIzaSyA7wCJB71I4L0XGIebkuK34x13oN0KfRkg"
gmaps = googlemaps.Client(key=key)

# %% [markdown]
# ### Places

# %%
# this call takes any natrual language, uses google's super secret giga search algo
place_result = gmaps.places('korean restaurants in UC Irvine')

for place in place_result['results']:
    print(place['name'])
# Out:
# YUP DDUK IRVINE
# Yoo's place
# Kalbi Social Club
# Youngdabang
# California Gogi
# Moobongri Soondae Irvine Barranca (무봉리 순대국 얼바인 바랑카)
# Yigah Restaurant
# Seoul N Spirits BBQ
# Yuk Dae Jang Irvine
# BCD Tofu House
# GOOYI92
# Hanshin Pocha Irvine
# Seoul Haus
# CHD Korean Dumplings
# I Can Barbecue Korean Grill
# So Gong Dong Tofu & BBQ
# Umma's K-BBQ
# Ever After Tea Room & Eatery
# Dosirak Express
# Baekjeong Irvine

# %%
# place result is a dictionary with these keys (I think for our project only results useful)
place_result.keys()
# Out:
# dict_keys(['html_attributions', 'next_page_token', 'results', 'status'])

# %%
# results is an array of dictionaries with these keys 
results = place_result["results"][0]
place_result["results"][0].keys()
# Out:
# dict_keys(['business_status', 'formatted_address', 'geometry', 'icon', 'icon_background_color', 'icon_mask_base_uri', 'name', 'opening_hours', 'photos', 'place_id', 'price_level', 'rating', 'reference', 'types', 'user_ratings_total'])

# %%
print("Is it open now? ", results["opening_hours"]["open_now"])
print("Business stats:", results["business_status"])
print("Price level:", results["price_level"])
print("user ratings total:", results["user_ratings_total"])
print("Rating: ", results["rating"])
# Out:
# Is it open now?  True
# Business stats: OPERATIONAL
# Price level: 1
# user ratings total: 178
# Rating:  4.4

# %%
print("Every place open now: ")
for i in place_result["results"]:
    if i["opening_hours"]["open_now"]:
        print(i["name"], i["rating"])
# Out:
# Every place open now:
# YUP DDUK IRVINE 4.4
# Yoo's place 4.1
# Kalbi Social Club 4
# Youngdabang 4.8
# California Gogi 4
# Moobongri Soondae Irvine Barranca (무봉리 순대국 얼바인 바랑카) 4.4
# Yigah Restaurant 4.2
# Seoul N Spirits BBQ 4.3
# Yuk Dae Jang Irvine 4.2
# BCD Tofu House 4.3
# GOOYI92 4.5
# Seoul Haus 4.1
# CHD Korean Dumplings 4
# I Can Barbecue Korean Grill 4.3
# So Gong Dong Tofu & BBQ 4.8
# Umma's K-BBQ 4.7
# Ever After Tea Room & Eatery 4.6
# Dosirak Express 4.4
# Baekjeong Irvine 4.2
